# %% [markdown]
# ## INST414 | Assignment 3 - Module 3 | Daniel Hernandez Gonzalez

# %%
# Pandas, we all love them. 
import pandas as pd

#spotify tools.
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Tools for making calculations
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %% [markdown]
# # Authenticating with Spotify API

# %%
# Authentication keys, taken out from my final push.
client_id = '******'
client_secret = '******'
username = '*****'

# set up Spotify API credentials
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# # Gathering data

# %%
# It is more efficient to make a function to do this set of instructions instead of writing it more than once. 
def get_songs(genre):
    # First set of 50 songs, search query and parameters
    query = f'genre:{genre}, year:2022'
    limit = 50
    offset = 0

    # Spotify API call for first 50 songs
    results1 = sp.search(q=query, type='track', limit=limit, offset=offset)

    # Second set of 50 songs, new offset
    offset = 50

    # Second API request
    results2 = sp.search(q=query, type='track', limit=limit, offset=offset)

    # third set of 50 songs, new offset
    offset = 100

    # Third API call
    results3 = sp.search(q=query, type='track', limit=limit, offset=offset)
    
    # Merging results and creating list of top 150 songs
    top_songs = results1['tracks']['items'] + results2['tracks']['items'] + results3['tracks']['items']
    
    return top_songs

# %%
# Gathering top 150 songs from 2022 for the following genres. 
# I chose specific genres based on the genres shown on Spotify's platform and a few that I am interested in. Genre page: https://open.spotify.com/genre/hub-browse-grid

genre_list = ['rap', 'pop', 'house', 'country', 'rock', 'soul', 'inde', 'punk', 'corrido', 'banda']

# Creating an empty DataFrame with columns.
songs_df = pd.DataFrame(columns=['track_id', 'track_name', 'artist_name', 'genre', 'tempo', 'popularity', 'acousticness', 'danceability', 'energy', 'loudness'])

# %%
# Iterating over the genres and tracks to add data into songs_df
for genre in genre_list:
    genre_songs = get_songs(genre)
    for track in genre_songs:
        track_id = track['id']
        artist_names = [artist['name'] for artist in track['album']['artists']]
        artist_name = ', '.join(artist_names)
        track_name = track['name']
        popularity = track['popularity']
        genre = genre

        # Spotify API call to get additional audio features
        audio_features = sp.audio_features(track_id)
        if audio_features:
            acousticness = audio_features[0]['acousticness']
            danceability = audio_features[0]['danceability']
            energy = audio_features[0]['energy']
            tempo = audio_features[0]['tempo']
            loudness = audio_features[0]['loudness']
        else:
            # Incase any missing values. Will drop after.
            acousticness, danceability, energy, tempo = None, None, None, None

        # adding all data to pulled into songs_df
        songs_df.loc[len(songs_df)] = [track_id, track_name, artist_name, genre, tempo, popularity, acousticness, danceability, energy, loudness]

# %%
# Dataframe size before cleaning
print(f'table size before cleaning: {songs_df.shape}') 

# Dropping duplicate track names if they have the same artist name
songs_df = songs_df.drop_duplicates(subset=['track_name', 'artist_name'])

# Dataframe size after cleaning and displaying table
print(f'\ntable size after cleaning: {songs_df.shape}\n') 
songs_df
# Out:
# table size before cleaning: (1500, 10)
#
# table size after cleaning: (1323, 10)
#                     track_id
# 0     4FyesJzVpA39hbYvcseO2d  \
# 1     1Qrg8KqiBpW07V7PNxwwwL
# 2     2dHHgzDwk4BJdRwy9uXhTO
# 3     1bDbXMyjaUIooNwFE9wn0N
# 4     0vjeOZ3Ft5jvAi9SBFJm1j
# ...                      ...
# 1495  03KHME9Npqhqzm8ivhghLX
# 1496  1uNo4WxrVKwGnSzyexALea
# 1497  1dtpnvjay5bEhEuui09YWx
# 1498  58HNUZW1ffosnXPPHDwDRz
# 1499  2rNksx1mb49Vb35MiKgUiJ
#
#                                              track_name
# 0                                       Just Wanna Rock  \
# 1                                             Kill Bill
# 2                Creepin' (with The Weeknd & 21 Savage)
# 3                                             Rich Flex
# 4     Superhero (Heroes & Villains) [with Future & C...
# ...                                                 ...
# 1495                                      Nomás Imagina
# 1496                                      Hoy Te Pierdo
# 1497                                Cómo Me Haces Falta
# 1498                                 Abrigame - En Vivo
# 1499  Popurrí Cumbias: Se Murió De Amor/Desvelado/Ot...
#
#                        artist_name  genre    tempo  popularity  acousticness
# 0                     Lil Uzi Vert    rap  150.187          91        0.0652  \
# 1                              SZA    rap   88.980          95        0.0521
# 2                     Metro Boomin    rap   97.950          96        0.4170
# 3                 Drake, 21 Savage    rap  153.150          91        0.0503
# 4                     Metro Boomin    rap  116.622          90        0.1520
# ...                            ...    ...      ...         ...           ...
# 1495  Banda MS de Sergio Lizárraga  banda  118.231          51        0.4640
# 1496                Alfredo Olivas  banda  179.975          60        0.0564
# 1497         Luis Angel "El Flaco"  banda  108.001          54        0.5000
# 1498                    Carin Leon  banda  114.359          52        0.0523
# 1499              Remmy Valenzuela  banda   98.103          54        0.3410
#
#       danceability  energy  loudness
# 0            0.486   0.545    -7.924
# 1            0.644   0.735    -5.747
# 2            0.715   0.620    -6.005
# 3            0.561   0.520    -9.342
# 4            0.526   0.606    -5.300
# ...            ...     ...       ...
# 1495         0.604   0.623    -6.495
# 1496         0.573   0.707    -6.748
# 1497         0.924   0.505    -4.342
# 1498         0.666   0.700    -3.929
# 1499         0.569   0.802    -4.654
#
# [1323 rows x 10 columns]

# %%
# Drops a row if it is missing a value.


print(f"{songs_df.shape}\n")

print(songs_df.isna().sum())
#songs_df.dropna(inplace=True)

#print(f"\n{songs_df.shape}")

# I was getting errors in pervious versions of my code. I kept this incase I wanted to come back and test different genres.
# Out:
# (1323, 10)
#
# track_id        0
# track_name      0
# artist_name     0
# genre           0
# tempo           0
# popularity      0
# acousticness    0
# danceability    0
# energy          0
# loudness        0
# dtype: int64

# %%
# pulling the top songs from each genre and sorting by popularity for better view.
top_songs_by_genre = songs_df.sort_values('popularity', ascending=False).groupby('genre').head(1)
top_songs_by_genre
# Out:
#                     track_id
# 2     2dHHgzDwk4BJdRwy9uXhTO  \
# 153   0WtM2NBVQNNJLh6scP13H8
# 1200  1lRtH4FszTrwwlK5gTSbXO
# 308   4zN21mbAuaD0WqtmaTZZeP
# 1351  5kpxVMDvYGRmNqawPqDTYR
# 612   3CIyK1V4JEJkg02E4EJnDl
# 452   48UKTR66uUOT9LaUvooTNx
# 760   48CKzGWOC65n8a8kdANJV8
# 1054  2ah5gOCogw00A62XBoepmc
# 900   21rpBPAlXAvBavvu5kCQzs
#
#                                              track_name
# 2                Creepin' (with The Weeknd & 21 Savage)  \
# 153                       Calm Down (with Selena Gomez)
# 1200                                                AMG
# 308                                             Ferrari
# 1351                                                JGL
# 612   Enemy (with JID) - from the series Arcane Leag...
# 452                            The Kind of Love We Make
# 760   Only Love Can Hurt Like This - Slowed Down Ver...
# 1054                                            Miracle
# 900                                      After Midnight
#
#                                         artist_name    genre    tempo
# 2                                      Metro Boomin      rap   97.950  \
# 153                              Rema, Selena Gomez      pop  106.999
# 1200  Natanael Cano, Peso Pluma, Gabito Ballesteros  corrido  136.175
# 308                     James Hype, Miggy Dela Rosa    house  125.004
# 1351                  La Adictiva, Luis R Conriquez    banda  112.852
# 612                                 Imagine Dragons     rock   77.011
# 452                                      Luke Combs  country  102.025
# 760                  Paloma Faith, sped up + slowed     soul   82.012
# 1054                              A Day To Remember     punk  160.028
# 900                                         Phoenix     inde  100.010
#
#       popularity  acousticness  danceability  energy  loudness
# 2             96      0.417000         0.715   0.620    -6.005
# 153           96      0.382000         0.801   0.806    -5.206
# 1200          95      0.152000         0.772   0.730    -6.657
# 308           86      0.012700         0.847   0.690    -7.877
# 1351          84      0.550000         0.702   0.586    -5.317
# 612           83      0.237000         0.728   0.783    -4.424
# 452           82      0.022600         0.608   0.745    -4.130
# 760           74      0.102000         0.554   0.854    -6.263
# 1054          68      0.000266         0.463   0.917    -3.776
# 900           61      0.002450         0.618   0.811    -6.654

# %% [markdown]
# #### As a disclaimer, I am aware that this is alphabetically the top song per genre based on sorting by popularity.

# %% [markdown]
# # Distance calculations

# %% [markdown]
# ### My goal:
#     - Grab the top songs from each genre.
#     - Calculate Euclidean distance between songs.
#     - print top 10 closest songs

# %%
def closest_tracks(track_id, songs_df):
    # Extracting audio features for the provided track
    audio_features = songs_df.loc[songs_df['track_id'] == track_id, ['tempo', 'acousticness', 'danceability', 'energy', 'loudness']]

    # Calculating Euclidean distance between the provided track and all other tracks
    songs_df.loc[:,'distance'] = np.sqrt((songs_df['tempo'] - audio_features['tempo'].iloc[0])**2 +
                                    (songs_df['danceability'] - audio_features['danceability'].iloc[0])**2 +
                                    (songs_df['acousticness'] - audio_features['acousticness'].iloc[0])**2 +
                                    (songs_df['energy'] - audio_features['energy'].iloc[0])**2 + 
                                    (songs_df['loudness'] - audio_features['loudness'].iloc[0])**2)

    # Sorting the DataFrame by distance in ascending order
    songs_df = songs_df.sort_values('distance')

    # Adding the input track back to the top of the DataFrame
    input_track = songs_df.loc[songs_df['track_id'] == track_id]

    # Adding closest tracks to new dataframe
    closest_tracks = pd.concat([input_track, songs_df.loc[((songs_df['track_name'] != input_track['track_name'].iloc[0]) |
                                        (songs_df['artist_name'] != input_track['artist_name'].iloc[0])) &
                                        (songs_df['track_id'] != input_track['track_id'].iloc[0])].head(10)])

    # Resetting the index and dropping old index to avoid too many numbers. 
    closest_tracks = closest_tracks.reset_index(drop=True)

    return closest_tracks

# %% [markdown]
# ### What are the closest songs in comparison to the top rap song?

# %%
rap_id = '2dHHgzDwk4BJdRwy9uXhTO' # "'Creepin' (with The Weeknd & 21 Savage)"
closest_rap = closest_tracks(rap_id, songs_df)
closest_rap
# Out:
#                   track_id                              track_name
# 0   2dHHgzDwk4BJdRwy9uXhTO  Creepin' (with The Weeknd & 21 Savage)  \
# 1   4ZUpTMKPYFTfJqamWFU9Zv                  IDGAF (with blackbear)
# 2   4uk8GguFehn7djGvFJTUUT                             Enloquecido
# 3   5Ei8EK2uXNkqqVSe2QYsFp                        Que Te Vaya Bien
# 4   3bvJftZKZe5QKz433NczyV                           No Es Por Acá
# 5   6Awl7JBDQjfm7xkS3LkhDi                          We Got History
# 6   1VMBapbhHidf6ALFszT7w1                                  Lonely
# 7   3G1nE9ZEv4eGEM48IAIv8u                              Millennium
# 8   1zsPaEkglFvxjAhrM8yhpr                                 Hey Mor
# 9   6Rpbzk2LC8xWZI93RyodAq                                 Hey Mor
# 10  2ZlABhxMMa43COmZ97kKsJ                   Jumbotron Shit Poppin
#
#                           artist_name    genre   tempo  popularity
# 0                        Metro Boomin      rap  97.950          96  \
# 1                          BoyWithUke      rap  97.975          76
# 2                    Grupo Arriesgado  corrido  98.053          71
# 3   Julión Álvarez y su Norteño Banda    banda  97.990          76
# 4                          Carin Leon  corrido  97.568          82
# 5                   Mitchell Tenpenny  country  98.025          74
# 6                     Imagine Dragons     rock  97.983          73
# 7                          Toro y Moi     soul  98.055          51
# 8                               Ozuna      pop  98.002          92
# 9                         Ozuna, Feid      pop  98.002          84
# 10                   Drake, 21 Savage      rap  99.026          76
#
#     acousticness  danceability  energy  loudness  distance
# 0        0.41700         0.715   0.620    -6.005  0.000000
# 1        0.42700         0.782   0.728    -5.930  0.150010
# 2        0.25000         0.784   0.734    -6.007  0.237190
# 3        0.23700         0.667   0.467    -5.906  0.263655
# 4        0.45600         0.746   0.370    -6.309  0.550747
# 5        0.00140         0.628   0.833    -6.327  0.578766
# 6        0.02560         0.714   0.730    -5.564  0.600720
# 7        0.32500         0.687   0.691    -6.743  0.754956
# 8        0.00302         0.901   0.589    -6.713  0.843151
# 9        0.00302         0.901   0.589    -6.713  0.843151
# 10       0.22100         0.799   0.575    -6.257  1.126400

# %% [markdown]
# ### What are the closest songs in comparison to the top corrido song?

# %%
corrido_id = '1lRtH4FszTrwwlK5gTSbXO' # "AMG"
closest_corrido = closest_tracks(corrido_id, songs_df)
closest_corrido
# Out:
#                   track_id                             track_name
# 0   1lRtH4FszTrwwlK5gTSbXO                                    AMG  \
# 1   3gfSH9aYZbyGjdmbeoWliw                     Siempre Pendientes
# 2   5gVCfYmQRPy1QJifP8f5gg                           Fall In Love
# 3   1wLNEMiUzwvRZz9XHCXhAE                           Fifth of May
# 4   1ENsFKcyksWFyXNQlWCI1c                 Mirate Nomas (En Vivo)
# 5   6AhwAWzSlISc5ZvGonkgdN                            Playing God
# 6   5VfkfKTTo5BRKqHwfENF0V                          Míranos Ahora
# 7   46FdwGMcgz6gik4RCpWBAW                           Los Collares
# 8   45bfH0GZvUyujIBiKRhXso         B.O.T.A. (Baddest Of Them All)
# 9   39JofJHEtg8I4fSyo7Imft  B.O.T.A. (Baddest Of Them All) - Edit
# 10  6y2JZ4hqjdJiEINCrdJkiN                           Memento Mori
#
#                                       artist_name    genre    tempo
# 0   Natanael Cano, Peso Pluma, Gabito Ballesteros  corrido  136.175  \
# 1                    Peso Pluma, Luis R Conriquez  corrido  135.929
# 2                                Bailey Zimmerman      pop  135.962
# 3                                      Zach Bryan  country  136.728
# 4                                  Ulices Chaidez    banda  135.836
# 5                                        Polyphia     rock  137.060
# 6                                      Calibre 50  corrido  135.832
# 7                 Oscar Maydon, El Padrinito Toys  corrido  136.724
# 8             Eliza Rose, Interplanetary Criminal    house  136.981
# 9             Eliza Rose, Interplanetary Criminal    house  137.001
# 10                                 Lucio Bukowski     inde  134.976
#
#     popularity  acousticness  danceability  energy  loudness  distance
# 0           95        0.1520         0.772   0.730    -6.657  0.000000
# 1           87        0.3310         0.774   0.748    -7.086  0.526238
# 2           80        0.4510         0.524   0.643    -6.055  0.752494
# 3           72        0.3910         0.596   0.544    -7.039  0.757909
# 4           55        0.5820         0.653   0.375    -7.060  0.776155
# 5           67        0.0395         0.601   0.789    -6.822  0.925110
# 6           70        0.6510         0.680   0.439    -5.909  1.009603
# 7           86        0.2080         0.645   0.712    -5.787  1.038215
# 8           67        0.0671         0.756   0.962    -7.526  1.210820
# 9           82        0.1640         0.736   0.906    -7.589  1.258299
# 10          10        0.1530         0.778   0.652    -6.235  1.273501

# %% [markdown]
# ### What are the closest songs in comparison to the top Banda song?

# %%
banda_id = '5kpxVMDvYGRmNqawPqDTYR' # "JGL"
closest_banda = closest_tracks(banda_id, songs_df)
closest_banda
# Out:
#                   track_id                              track_name
# 0   5kpxVMDvYGRmNqawPqDTYR                                     JGL  \
# 1   0RstZCli3DcyY1LJq38P4b                               El Chaman
# 2   42cVZAhX13JCHwrvlfqLcB                   When You Lose Someone
# 3   1xTYy3K3hiTcoZfoD7culn        Say You Want Me - Single Version
# 4   6DL44bNYvHzr1E58BAx5zx                   Horseshit on Route 66
# 5   66MvNxKQGPQS0AUeaoYlcn                                hair out
# 6   5Tg3TbTftDrjmQORfsqw5m                       Enamorado Y Feliz
# 7   5DAkzBJ48N7z6lwY4eZ0PP                                Artefact
# 8   11kskoMyNDumaR30CI6rRv                              Half Of Me
# 9   69w5X6uTrOaWM32IetSzvO                             Daydreaming
# 10  1pacwLXyRO47ka0v6LTIiY  Raindrops (Insane) [with Travis Scott]
#
#                       artist_name    genre    tempo  popularity  acousticness
# 0   La Adictiva, Luis R Conriquez    banda  112.852          84      0.550000  \
# 1              Gabito Ballesteros  corrido  112.998          69      0.260000
# 2                         The Dip     soul  112.452          53      0.365000
# 3                          Masego     soul  112.978          63      0.190000
# 4                      The Garden     punk  112.328          49      0.028300
# 5                  Stand Atlantic     punk  112.987          53      0.000488
# 6                     La Adictiva    banda  113.590          50      0.377000
# 7                         Phoenix     inde  112.025          53      0.007840
# 8                    Thomas Rhett  country  111.995          69      0.006830
# 9                    Harry Styles      pop  113.971          77      0.311000
# 10                   Metro Boomin      rap  111.988          79      0.103000
#
#     danceability  energy  loudness  distance
# 0          0.702   0.586    -5.317  0.000000
# 1          0.814   0.575    -5.348  0.345025
# 2          0.751   0.498    -5.766  0.637159
# 3          0.884   0.658    -5.940  0.756249
# 4          0.498   0.978    -5.115  0.884777
# 5          0.678   0.896    -4.685  0.903487
# 6          0.653   0.434    -5.895  0.966521
# 7          0.705   0.636    -5.734  1.074367
# 8          0.575   0.842    -5.058  1.085462
# 9          0.707   0.811    -5.298  1.166316
# 10         0.796   0.539    -5.974  1.178558
